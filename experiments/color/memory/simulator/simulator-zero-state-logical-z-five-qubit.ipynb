# %% [markdown]
# # Memory experiment: Compute $ \langle \bar{0} | \bar{Z} | \bar{0} \rangle$ with the five-qubit code

# %%
from typing import List, Dict, Sequence
import itertools
import functools
import numpy as np
import cirq
import qiskit
import qiskit_ibm_runtime
from qiskit_aer import AerSimulator

import matplotlib.pyplot as plt

from mitiq import PauliString

from encoded.diagonalize import get_stabilizer_matrix_from_paulis, get_measurement_circuit, get_paulis_from_stabilizer_matrix

# %% [markdown]
# ## Set parameters

# %%
n = 5                                   # Number of physical qubits
nshots = 100_000                        # Number of samples/shots
depths = np.arange(0, 240 + 1, 20)      # Number of X (NOT) gates to perform (each depth should be even to implement a noisy identity)
k = 1                                   # Number of logical qubits.

# %%
# Computer and qubits to use.
# Option 1: Use saved noise characteristics.
computer = qiskit_ibm_runtime.fake_provider.FakeKyiv#()
# computer = AerSimulator()  # Noiseless simulator - use this for a sanity check to see all computed expectation values (physical and encoded) are 1.0.

# Option 2: Use noise characteristics from most recent calibration.
# service = qiskit_ibm_runtime.QiskitRuntimeService()  # This assumes a saved account.
# computer = service.backend("ibm_kyiv")
# computer = AerSimulator.from_backend(computer)

# See calibration data at https://quantum.ibm.com/services/resources to select good qubits.
layout = {
    1 : [4],
    5 : [4, 15, 21, 22, 23],
}

# %% [markdown]
# ## Helper functions

# %%
# Expectation of pauli on bitstring measured in diagonal basis.
def compute_expectation(
    pauli: cirq.PauliString,
    counts: Dict[str, int],
) -> float:
    if pauli is cirq.PauliString():
        return 1.0

    expectation = 0.0

    indices = [q.x for q in pauli.qubits]
    for key, value in counts.items():
        key = list(map(int, list(key[::-1])))
        expectation += (-1) ** sum([key[i] for i in indices]) * value

    return expectation / sum(counts.values())

# Prepares logical |0> state on Steane Code
def encode_five(qreg: Sequence[cirq.Qid]) -> cirq.Circuit:
    circuit = cirq.Circuit()

    sdg = cirq.S**-1
    circuit = cirq.Circuit()
    circuit.append(cirq.Z.on(qreg[0]))
    circuit.append(cirq.H.on(qreg[2]))
    circuit.append(cirq.H.on(qreg[3]))
    circuit.append(sdg.on(qreg[0]))
    circuit.append(cirq.CNOT.on(qreg[2], qreg[4]))
    circuit.append(cirq.CNOT.on(qreg[3], qreg[1]))
    circuit.append(cirq.CNOT.on(qreg[3], qreg[4]))
    circuit.append(cirq.H.on(qreg[1]))
    circuit.append(sdg.on(qreg[2]))
    circuit.append(sdg.on(qreg[4]))
    circuit.append(cirq.S.on(qreg[3]))
    circuit.append(cirq.CNOT.on(qreg[1], qreg[0]))

    circuit.append(cirq.S.on(qreg[0]))
    circuit.append(cirq.S.on(qreg[1]))
    circuit.append(cirq.Z.on(qreg[2]))
    circuit.append(cirq.CNOT.on(qreg[4], qreg[0]))
    circuit.append(cirq.H.on(qreg[4]))
    circuit.append(cirq.CNOT.on(qreg[4], qreg[1]))

    return circuit

def noisy_identity(qreg, depth):
    circuit = cirq.Circuit()
    if depth == 0:
        circuit.append(cirq.I.on_each(qreg))
    for _ in range(depth):
        circuit.append(cirq.X.on_each(qreg))
    return circuit

def strs_to_paulis(pauli_strs : List[str]) -> List[cirq.PauliString]:
    stab_list = []
    for stab_str in pauli_strs:
        stab_list.append(PauliString(stab_str)._pauli)
    return stab_list

def generate_stabilizer_elements(generators: List[cirq.PauliString]) -> List[cirq.PauliString]:
    elements = []
    for string in itertools.chain.from_iterable(itertools.combinations(generators, r) for r in range(len(generators) + 1)):
        elements.append(
            functools.reduce(lambda a, b: a * b, string, cirq.PauliString())
        )
    return elements

# For qiskit circuits
def get_active_qubits(circ):
    dag = qiskit.converters.circuit_to_dag(circ)
    active_qubits = [qubit for qubit in circ.qubits if qubit not in dag.idle_wires()]
    return active_qubits

def get_lst_ev(counts, observables, stabilizers):
    numerator = 0
    for obs in observables:
        numerator += compute_expectation(obs, counts) / len(observables)
    denominator = 0
    for stab in stabilizers:
        denominator += compute_expectation(stab, counts) / len(stabilizers)
    return float(np.real_if_close(numerator / denominator))

# %% [markdown]
# ### Run unmitigated experiment

# %%
qreg = cirq.LineQubit.range(k)

unmit_evs = []
for depth in depths:
    circuit = noisy_identity(qreg, depth)

    circuit = qiskit.QuantumCircuit.from_qasm_str(circuit.to_qasm())
    circuit.measure_active()
    # Compile to device.
    compiled_raw = qiskit.transpile(
        circuit, 
        backend=computer,
        initial_layout=layout[1],  # Hardcode n = 1 (i.e., no encoding) to get layout.
        routing_method="sabre",
        # scheduling_method="asap",
        optimization_level=0,
    )

    job = computer.run(compiled_raw, shots=nshots)
    counts = job.result().get_counts()
    ev = compute_expectation(PauliString("Z")._pauli, counts)

    unmit_evs.append(ev)
    print(ev)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 10
#       8 circuit.measure_active()
#       9 # Compile to device.
# ---> 10 compiled_raw = qiskit.transpile(
#      11     circuit,
#      12     backend=computer,
#      13     initial_layout=layout[1],  # Hardcode n = 1 (i.e., no encoding) to get layout.
#      14     routing_method="sabre",
#      15     # scheduling_method="asap",
#      16     optimization_level=0,
#      17 )
#      19 job = computer.run(compiled_raw, shots=nshots)
#      20 counts = job.result().get_counts()
#
# File ~/Documents/encoded/venv/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File ~/Documents/encoded/venv/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
#     [... skipping similar frames: deprecate_arg.<locals>.decorator.<locals>.wrapper at line 184 (1 times)]
#
# File ~/Documents/encoded/venv/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File ~/Documents/encoded/venv/lib/python3.12/site-packages/qiskit/compiler/transpiler.py:392, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods, num_processes, qubits_initially_zero)
#     390 output_name = _parse_output_name(output_name, circuits)
#     391 coupling_map = _parse_coupling_map(coupling_map)
# --> 392 _check_circuits_coupling_map(circuits, coupling_map, backend)
#     394 # Edge cases require using the old model (loose constraints) instead of building a target,
#     395 # but we don't populate the passmanager config with loose constraints unless it's one of
#     396 # the known edge cases to control the execution path.
#     397 # Filter instruction_durations, timing_constraints, backend_properties and inst_map deprecation
#     398 with warnings.catch_warnings():
#
# File ~/Documents/encoded/venv/lib/python3.12/site-packages/qiskit/compiler/transpiler.py:472, in _check_circuits_coupling_map(circuits, cmap, backend)
#     469 for circuit in circuits:
#     470     # If coupling_map is not None or num_qubits == 1
#     471     num_qubits = len(circuit.qubits)
# --> 472     if max_qubits is not None and (num_qubits > max_qubits):
#     473         raise CircuitTooWideForTarget(
#     474             f"Number of qubits ({num_qubits}) in {circuit.name} "
#     475             f"is greater than maximum ({max_qubits}) in the coupling_map"
#     476         )
#
# TypeError: '>' not supported between instances of 'int' and 'property'

# %% [markdown]
# # Run encoded experiment

# %%
generator_strs = [
    "XZZXI",
    "IXZZX",
    "XIXZZ", 
    "ZXIXZ"
]

observable = PauliString("Z" * n)._pauli

qreg = cirq.LineQubit.range(n)

stabilizer_generators = strs_to_paulis(generator_strs)
stabilizer_matrix = get_stabilizer_matrix_from_paulis(stabilizer_generators, qreg)
measurement_circuit, transformed_matrix = get_measurement_circuit(stabilizer_matrix)

transformed_generators = get_paulis_from_stabilizer_matrix(transformed_matrix)
stabilizer_elements = generate_stabilizer_elements(transformed_generators)
# for stab in stabilizer_elements:
#     print(stab)

transformed_observable = observable.conjugated_by(measurement_circuit**-1)
observable_elements = [transformed_observable * stab for stab in stabilizer_elements]
for obs in observable_elements:
    print(obs)
print(measurement_circuit)
# Out:
# Z(q(4))
# Z(q(0))*Z(q(4))
# Z(q(1))*Z(q(4))
# Z(q(2))
# Z(q(3))
# Z(q(0))*Z(q(1))*Z(q(4))
# Z(q(0))*Z(q(2))
# Z(q(0))*Z(q(3))
# Z(q(1))*Z(q(2))
# Z(q(1))*Z(q(3))
# Z(q(2))*Z(q(3))*Z(q(4))
# Z(q(0))*Z(q(1))*Z(q(2))
# Z(q(0))*Z(q(1))*Z(q(3))
# Z(q(0))*Z(q(2))*Z(q(3))*Z(q(4))
# Z(q(1))*Z(q(2))*Z(q(3))*Z(q(4))
# Z(q(0))*Z(q(1))*Z(q(2))*Z(q(3))*Z(q(4))
#       ┌──┐                       ┌──┐
# 0: ────@─────────X───────@───@─────@────H───────────
#        │         │       │   │     │
# 1: ────┼@────────┼───X───@───┼────@┼────@───H───────
#        ││        │   │       │    ││    │
# 2: ────┼┼────@───@───┼───────@────@┼────┼───@───H───
#        ││    │       │             │    │   │
# 3: ────X┼────X───@───@─────────────@────@───@───H───
#         │        │
# 4: ─────X────────X──────────────────────────────────
#       └──┘                       └──┘

# %%
from qiskit.circuit.library import Barrier
encoding = encode_five(qreg)
encoding = qiskit.QuantumCircuit.from_qasm_str(encoding.to_qasm())

measurement = qiskit.QuantumCircuit.from_qasm_str(measurement_circuit.to_qasm())

circ_full = encoding.compose(
        Barrier(n, label="encoding"), get_active_qubits(encoding)
    ).compose(Barrier(n, label="measurement"), get_active_qubits(encoding)
).compose(measurement)
circ_full.measure_active()

noiseless_compiled = qiskit.transpile(
    circ_full, 
    backend=computer,
    initial_layout=layout[n],
    routing_method="sabre",
    # scheduling_method="asap",
    optimization_level=3,
)

noiseless_compiled.draw(fold=-1, idle_wires=False)
noiseless_compiled.count_ops()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 13
#       7 circ_full = encoding.compose(
#       8         Barrier(n, label="encoding"), get_active_qubits(encoding)
#       9     ).compose(Barrier(n, label="measurement"), get_active_qubits(encoding)
#      10 ).compose(measurement)
#      11 circ_full.measure_active()
# ---> 13 noiseless_compiled = qiskit.transpile(
#      14     circ_full,
#      15     backend=computer,
#      16     initial_layout=layout[n],
#      17     routing_method="sabre",
#      18     # scheduling_method="asap",
#      19     optimization_level=3,
#      20 )
#      22 noiseless_compiled.draw(fold=-1, idle_wires=False)
#      23 noiseless_compiled.count_ops()
#
# File ~/Documents/encoded/venv/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File ~/Documents/encoded/venv/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
#     [... skipping similar frames: deprecate_arg.<locals>.decorator.<locals>.wrapper at line 184 (1 times)]
#
# File ~/Documents/encoded/venv/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File ~/Documents/encoded/venv/lib/python3.12/site-packages/qiskit/compiler/transpiler.py:392, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods, num_processes, qubits_initially_zero)
#     390 output_name = _parse_output_name(output_name, circuits)
#     391 coupling_map = _parse_coupling_map(coupling_map)
# --> 392 _check_circuits_coupling_map(circuits, coupling_map, backend)
#     394 # Edge cases require using the old model (loose constraints) instead of building a target,
#     395 # but we don't populate the passmanager config with loose constraints unless it's one of
#     396 # the known edge cases to control the execution path.
#     397 # Filter instruction_durations, timing_constraints, backend_properties and inst_map deprecation
#     398 with warnings.catch_warnings():
#
# File ~/Documents/encoded/venv/lib/python3.12/site-packages/qiskit/compiler/transpiler.py:472, in _check_circuits_coupling_map(circuits, cmap, backend)
#     469 for circuit in circuits:
#     470     # If coupling_map is not None or num_qubits == 1
#     471     num_qubits = len(circuit.qubits)
# --> 472     if max_qubits is not None and (num_qubits > max_qubits):
#     473         raise CircuitTooWideForTarget(
#     474             f"Number of qubits ({num_qubits}) in {circuit.name} "
#     475             f"is greater than maximum ({max_qubits}) in the coupling_map"
#     476         )
#
# TypeError: '>' not supported between instances of 'int' and 'property'

# %% [markdown]
# ### Add (noisy) identity to circuit and compute expectation values

# %%
mit_evs = []
for depth in depths:
    compiled = noiseless_compiled.copy_empty_like()
    for instruction in noiseless_compiled.data:
        if instruction.label == "measurement":
            for _ in range(depth):
                for q in get_active_qubits(compiled):
                    compiled.x(q)
        compiled.append(
            instruction, instruction.qubits
        )
        
    job = computer.run(
        compiled,
        shots=nshots,
    )
    counts = job.result().get_counts()
    ev = get_lst_ev(counts, observable_elements, stabilizer_elements)
    mit_evs.append(ev)
    print(ev)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 13
#       8                 compiled.x(q)
#       9     compiled.append(
#      10         instruction, instruction.qubits
#      11     )
# ---> 13 job = computer.run(
#      14     compiled,
#      15     shots=nshots,
#      16 )
#      17 counts = job.result().get_counts()
#      18 ev = get_lst_ev(counts, observable_elements, stabilizer_elements)
#
# TypeError: FakeBackendV2.run() missing 1 required positional argument: 'run_input'

# %% [markdown]
# ### Make the measurement/diagonalization circuit noiseless and compute expectation values

# %%
from qiskit.circuit.library import UnitaryGate
from qiskit.transpiler import InstructionProperties

ideal_props = {
    (i,) : InstructionProperties(error=0.0, duration=0.0) for i in range(computer.num_qubits)
}

computer.target.add_instruction(UnitaryGate([[1, 0], [0, 1]]), ideal_props)
print(computer.target._gate_map['unitary'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 5
#       1 from qiskit.circuit.library import UnitaryGate
#       2 from qiskit.transpiler import InstructionProperties
#       4 ideal_props = {
# ----> 5     (i,) : InstructionProperties(error=0.0, duration=0.0) for i in range(computer.num_qubits)
#       6 }
#       8 computer.target.add_instruction(UnitaryGate([[1, 0], [0, 1]]), ideal_props)
#       9 print(computer.target._gate_map['unitary'])
#
# TypeError: 'property' object cannot be interpreted as an integer

# %%
from qiskit.circuit.library import UnitaryGate
noiseless_compiled_perfect_measurment = noiseless_compiled.copy_empty_like()

enc = True
mea = False
for instruction in noiseless_compiled.data:
    # print(instruction)
    if not mea and instruction.label != "encoding" and instruction.label != "measurement":
        op = instruction
    elif instruction.label == "encoding":
        enc = False
        op = instruction
    elif instruction.label == "measurement":
        mea = True
        op = instruction
    elif instruction.matrix is None:
        op = instruction
    else:
        op = UnitaryGate(instruction.matrix, label="ideal_" + instruction.operation.name)
    noiseless_compiled_perfect_measurment.append(
        op, instruction.qubits
    )
# print(noiseless_compiled_perfect_measurment.count_ops())
noiseless_compiled_perfect_measurment.draw(fold=-1, idle_wires=False)
# Out:
# global phase: 3π/4
#               ┌────┐                                                                                                          ┌──────┐   ┌────┐   ┌──────────┐                                                                                                                                                                                                                                                               ┌──────┐┌─────────┐ ┌────┐  ┌─────────┐                                        encoding  measurement ┌──────────┐┌──────────┐                                                                                      ┌────────────┐┌──────────┐┌──────────┐┌──────────┐┌────────────┐┌──────────┐┌──────────┐┌──────────┐┌────────────┐┌─────────┐                                                                                                                                                                                                                                                                                                                                   ┌────────────┐┌──────────┐┌──────────┐┌──────────┐                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ░             ┌─┐
#   q_0 -> 4 ───┤ √X ├──────────────────────────────────────────────────────────────────────────────────────────────────────────┤0     ├───┤ √X ├───┤ Rz(-π/2) ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0     ├┤ Rz(π/2) ├─┤ √X ├──┤ Rz(π/2) ├───────────────────────────────────────────░───────────░──────┤ ideal_rz ├┤ ideal_sx ├──────────────────────────────────────────────────────────────────────────────────────┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_x ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────░─────────────┤M├
#            ┌──┴────┴─┐ ┌────┐┌─────────────┐┌────┐┌──────────┐┌──────┐  ┌─────────┐   ┌────┐ ┌──────────────┐┌────┐┌─────────┐│  Ecr │┌──┴────┴─┐ └──┬────┬──┘┌─────────────┐ ┌────┐  ┌─────────┐                                                                                         ┌──────┐┌─────────┐ ┌────┐          ┌──────┐┌──────────┐                 ┌──────┐┌──────────┐┌────┐┌─────────────┐┌────┐┌─────────┐│  Ecr │├─────────┴┐├────┤┌─┴─────────┴─┐┌──────┐┌─────────┐ ┌────┐ ┌────────┐    ░           ░      ├──────────┤├──────────┤┌──────────┐┌──────────┐┌──────────┐┌────────────┐┌──────────┐┌──────────┐┌──────────┐│  ideal_ecr │├──────────┤├──────────┤└──────────┘│  ideal_ecr │├──────────┤└──────────┘└──────────┘│  ideal_ecr │├─────────┴┐┌──────────┐┌──────────┐┌──────────┐┌──────────┐┌────────────┐┌──────────┐┌──────────┐┌──────────┐                                                              ┌────────────┐┌──────────┐┌──────────┐            ┌────────────┐┌──────────┐                        ┌────────────┐┌──────────┐┌──────────┐┌──────────┐┌──────────┐│  ideal_ecr │├──────────┤├──────────┤├──────────┤┌──────────┐ ┌──────────┐                                                                                                                                         ┌────────────┐┌──────────┐┌──────────┐ ┌──────────┐                                                                                                                                                                                                                                                                                                                       ┌────────────┐┌──────────┐┌──────────┐            ┌────────────┐┌──────────┐                        ┌────────────┐┌──────────┐┌──────────┐ ┌──────────┐ ┌──────────┐                                                                          ┌────────────┐┌──────────┐┌──────────┐┌──────────┐┌──────────┐┌──────────┐ ░       ┌─┐   └╥┘
#  q_1 -> 15 ┤ Rz(π/2) ├─┤ √X ├┤ Rz(-2.0999) ├┤ √X ├┤ Rz(-π/2) ├┤1     ├──┤ Rz(π/2) ├───┤ √X ├─┤ Rz(-0.56479) ├┤ √X ├┤ Rz(π/2) ├┤1     ├┤ Rz(π/2) ├────┤ √X ├───┤ Rz(-3.1059) ├─┤ √X ├──┤ Rz(π/2) ├─────────────────────────────────────────────────────────────────────────────────────────┤1     ├┤ Rz(π/2) ├─┤ √X ├──────────┤1     ├┤ Rz(-π/2) ├─────────────────┤1     ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-2.8767) ├┤ √X ├┤ Rz(π/2) ├┤1     ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-1.3059) ├┤1     ├┤ Rz(π/2) ├─┤ √X ├─┤ Rz(-π) ├────░───────────░──────┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤1           ├┤ ideal_rz ├┤ ideal_sx ├────────────┤1           ├┤ ideal_rz ├────────────────────────┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├──────────────────────────────────────────────────────────────┤1           ├┤ ideal_rz ├┤ ideal_sx ├────────────┤1           ├┤ ideal_rz ├────────────────────────┤1           ├┤ ideal_sx ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤ ideal_sx ├─┤ ideal_rz ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1           ├┤ ideal_rz ├┤ ideal_sx ├─┤ ideal_rz ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1           ├┤ ideal_rz ├┤ ideal_sx ├────────────┤1           ├┤ ideal_rz ├────────────────────────┤1           ├┤ ideal_sx ├┤ ideal_rz ├─┤ ideal_sx ├─┤ ideal_rz ├──────────────────────────────────────────────────────────────────────────┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├─░───────┤M├────╫─
#            ├─────────┤ ├────┤└┬────────────┤└────┘└──────────┘│      │  └─────────┘   └────┘ └──────────────┘└────┘└─────────┘└──────┘└─────────┘    └────┘   └─────────────┘ └────┘  └─────────┘                   ┌──────┐   ┌───┐    ┌────────────┐                                    │      │└─────────┘ └────┘          │      │└──────────┘                 │      │└──────────┘└────┘└─────────────┘└────┘└─────────┘└──────┘└──────────┘└────┘└─────────────┘│      │└─────────┘ └────┘ └────────┘    ░           ░      ├─────────┬┘└──────────┘└──────────┘└──────────┘└──────────┘│            │└──────────┘└──────────┘└──────────┘└────────────┘└──────────┘└──────────┘            └────────────┘└──────────┘                        └────────────┘└──────────┘└──────────┘└──────────┘└──────────┘└──────────┘│            │└──────────┘└──────────┘└──────────┘┌────────────┐┌──────────┐                                    │            │└──────────┘└──────────┘            │            │└──────────┘                        │            │└──────────┘└──────────┘└──────────┘└──────────┘├────────────┤├──────────┤├──────────┤├──────────┤└──────────┘ └──────────┘                                                                                                                                         │            │└──────────┘└──────────┘ └──────────┘                                     ┌────────────┐┌──────────┐┌──────────┐┌──────────┐┌────────────┐┌──────────┐┌──────────┐┌──────────┐┌────────────┐┌──────────┐┌──────────┐                                                              ┌────────────┐┌──────────┐                                                │            │└──────────┘└──────────┘            │            │└──────────┘                        │            │└──────────┘└──────────┘ └──────────┘ └──────────┘                        ┌────────────┐┌──────────┐┌──────────┐┌──────────┐│            │└──────────┘└──────────┘└──────────┘└──────────┘└──────────┘ ░    ┌─┐└╥┘    ║
#  q_2 -> 21 ┤ Rz(π/2) ├─┤ √X ├─┤ Rz(2.7151) ├──────────────────┤  Ecr ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤0     ├───┤ X ├────┤ Rz(1.9973) ├────────────────────────────────────┤  Ecr ├────────────────────────────┤  Ecr ├─────────────────────────────┤  Ecr ├───────────────────────────────────────────────────────────────────────────────────────────┤  Ecr ├─────────────────────────────────░───────────░──────┤ ideal_x ├─────────────────────────────────────────────────┤  ideal_ecr ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤  ideal_ecr ├────────────────────────────────────┤0           ├┤ ideal_rz ├────────────────────────────────────┤  ideal_ecr ├────────────────────────────────────┤  ideal_ecr ├────────────────────────────────────┤  ideal_ecr ├────────────────────────────────────────────────┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤  ideal_ecr ├──────────────────────────────────────────────────────────────────────────┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_sx ├┤ ideal_rz ├──────────────────────────────────────────────────────────────┤0           ├┤ ideal_rz ├────────────────────────────────────────────────┤  ideal_ecr ├────────────────────────────────────┤  ideal_ecr ├────────────────────────────────────┤  ideal_ecr ├──────────────────────────────────────────────────────────────────────────┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤  ideal_ecr ├─────────────────────────────────────────────────────────────░────┤M├─╫─────╫─
#            ├─────────┴┐├────┤┌┴────────────┤                  │      │┌─────────────┐┌──────┐  ┌──────────┐  ┌────┐ ┌────────┐┌──────┐┌─────────┐    ┌────┐     ┌─────────┐  ┌──────┐┌────────────┐┌────┐┌─────────┐│  Ecr │┌──┴───┴───┐└───┬────┬───┘┌──────────────┐┌──────┐┌─────────┐ │      │┌──────────┐┌────┐┌────────┐│      │┌─────────┐ ┌────┐┌─────────┐│      │                                                                                           │      │┌──────────┐┌────┐┌─────────┐    ░           ░      └─────────┘                                                 │            │┌──────────┐┌──────────┐┌──────────┐┌────────────┐┌──────────┐┌──────────┐┌──────────┐┌────────────┐┌──────────┐┌──────────┐┌──────────┐┌────────────┐┌──────────┐                                                │            │┌──────────┐┌──────────┐┌──────────┐│  ideal_ecr │├──────────┤┌──────────┐┌──────────┐┌──────────┐│            │┌──────────┐┌──────────┐┌──────────┐│            │┌──────────┐┌──────────┐┌──────────┐│            │┌──────────┐┌──────────┐┌──────────┐┌──────────┐│  ideal_ecr │├──────────┤├──────────┤├──────────┤┌──────────┐┌────────────┐┌──────────┐┌──────────┐┌──────────┐┌────────────┐┌──────────┐┌──────────┐┌──────────┐┌────────────┐┌──────────┐┌──────────┐┌──────────┐│            │┌──────────┐┌──────────┐┌────────────┐┌──────────┐┌──────────┐┌──────────┐│  ideal_ecr │├──────────┤├──────────┤└──────────┘│  ideal_ecr │├──────────┤└──────────┘└──────────┘│  ideal_ecr │├──────────┤├──────────┤┌──────────┐┌────────────┐┌──────────┐┌──────────┐┌──────────┐│  ideal_ecr │├──────────┤┌──────────┐┌──────────┐┌──────────┐┌──────────┐│            │┌──────────┐┌──────────┐┌──────────┐│            │┌──────────┐┌──────────┐┌──────────┐│            │┌──────────┐┌─────────┐ ┌────────────┐┌──────────┐┌──────────┐┌──────────┐│  ideal_ecr │├──────────┤├──────────┤├──────────┤│            │┌──────────┐┌──────────┐┌──────────┐                         ░    └╥┘ ║ ┌─┐ ║
#  q_3 -> 22 ┤ Rz(-π/2) ├┤ √X ├┤ Rz(0.42859) ├──────────────────┤0     ├┤ Rz(0.42859) ├┤0     ├──┤ Rz(-π/2) ├──┤ √X ├─┤ Rz(-π) ├┤0     ├┤ Rz(π/2) ├────┤ √X ├─────┤ Rz(π/2) ├──┤0     ├┤ Rz(2.3042) ├┤ √X ├┤ Rz(π/2) ├┤1     ├┤ Rz(-π/2) ├────┤ √X ├────┤ Rz(-0.83735) ├┤0     ├┤ Rz(π/2) ├─┤0     ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├┤0     ├┤ Rz(π/2) ├─┤ √X ├┤ Rz(π/2) ├┤0     ├───────────────────────────────────────────────────────────────────────────────────────────┤0     ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/2) ├────░───────────░──────────────────────────────────────────────────────────────────┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├────────────────────────────────────────────────┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤ ideal_sx ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_sx ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤ ideal_sx ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤1           ├┤ ideal_rz ├┤ ideal_sx ├────────────┤1           ├┤ ideal_rz ├────────────────────────┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_x ├─┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├┤0           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├─────────────────────────░─────╫──╫─┤M├─╫─
#            ├─────────┬┘├────┤└──┬────────┬─┘                  └──────┘└─────────────┘│  Ecr │  ├─────────┬┘  ├────┤ └────────┘│  Ecr │├─────────┴┐   └────┘     └─────────┘  │  Ecr │└─┬────────┬─┘├────┤├─────────┤└──────┘└──────────┘    └────┘    └──────────────┘│  Ecr │├─────────┴┐└┬────┬┘├─────────┬┘└────┘└────────┘└──────┘└─────────┘ └────┘└─────────┘└──────┘                                                                                           └──────┘└──────────┘└────┘└─────────┘    ░           ░      ┌──────────┐┌──────────┐┌──────────┐                        └────────────┘└──────────┘└──────────┘└──────────┘│  ideal_ecr │├──────────┤├──────────┤└──────────┘│  ideal_ecr │├──────────┤└──────────┘└──────────┘│  ideal_ecr │├──────────┤                                                └────────────┘└──────────┘└──────────┘└──────────┘└────────────┘└──────────┘└──────────┘└──────────┘└──────────┘└────────────┘└──────────┘└──────────┘└──────────┘└────────────┘└──────────┘└──────────┘└──────────┘└────────────┘└──────────┘└──────────┘└──────────┘└──────────┘└────────────┘└──────────┘└──────────┘└──────────┘└──────────┘│  ideal_ecr │├──────────┤├──────────┤└──────────┘│  ideal_ecr │├──────────┤└──────────┘└──────────┘│  ideal_ecr │├──────────┤├──────────┤├──────────┤└┬──────────┬┘└──────────┘└──────────┘│  ideal_ecr │├──────────┤├──────────┤├──────────┤└┬──────────┬┘├──────────┤└──────────┘            └────────────┘└──────────┘                        └────────────┘└──────────┘└──────────┘└──────────┘│  ideal_ecr │├──────────┤├──────────┤├──────────┤└┬──────────┬┘├──────────┤└──────────┘└──────────┘└──────────┘└──────────┘└────────────┘└──────────┘└──────────┘└──────────┘└────────────┘└──────────┘└──────────┘└──────────┘└────────────┘└──────────┘└─────────┘ │  ideal_ecr │├──────────┤├──────────┤├──────────┤└┬──────────┬┘├──────────┤└──────────┘└──────────┘└────────────┘└──────────┘└──────────┘└──────────┘                         ░ ┌─┐ ║  ║ └╥┘ ║
#  q_4 -> 23 ┤ Rz(π/2) ├─┤ √X ├───┤ Rz(-π) ├───────────────────────────────────────────┤1     ├──┤ Rz(π/2) ├───┤ √X ├───────────┤1     ├┤ Rz(-π/2) ├───────────────────────────┤1     ├──┤ Rz(-π) ├──┤ √X ├┤ Rz(π/2) ├──────────────────────────────────────────────────┤1     ├┤ Rz(-π/2) ├─┤ √X ├─┤ Rz(π/2) ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────░───────────░──────┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├──────────────────────────────────────────────────────────────────────────┤1           ├┤ ideal_rz ├┤ ideal_sx ├────────────┤1           ├┤ ideal_rz ├────────────────────────┤1           ├┤ ideal_sx ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1           ├┤ ideal_rz ├┤ ideal_sx ├────────────┤1           ├┤ ideal_rz ├────────────────────────┤1           ├┤ ideal_sx ├┤ ideal_rz ├┤ ideal_sx ├─┤ ideal_rz ├─────────────────────────┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├─┤ ideal_sx ├─┤ ideal_rz ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├─┤ ideal_sx ├─┤ ideal_rz ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤1           ├┤ ideal_rz ├┤ ideal_sx ├┤ ideal_rz ├─┤ ideal_sx ├─┤ ideal_rz ├───────────────────────────────────────────────────────────────────────────────────────────────────░─┤M├─╫──╫──╫──╫─
#            └─────────┘ └────┘   └────────┘                                           └──────┘  └─────────┘   └────┘           └──────┘└──────────┘                           └──────┘  └────────┘  └────┘└─────────┘                                                  └──────┘└──────────┘ └────┘ └─────────┘                                                                                                                                                                                                  ░           ░      └──────────┘└──────────┘└──────────┘                                                                          └────────────┘└──────────┘└──────────┘            └────────────┘└──────────┘                        └────────────┘└──────────┘                                                                                                                                                                                                                                                                                                                                                                                                └────────────┘└──────────┘└──────────┘            └────────────┘└──────────┘                        └────────────┘└──────────┘└──────────┘└──────────┘ └──────────┘                         └────────────┘└──────────┘└──────────┘└──────────┘ └──────────┘ └──────────┘                                                                                                                            └────────────┘└──────────┘└──────────┘└──────────┘ └──────────┘ └──────────┘                                                                                                                                                                                          └────────────┘└──────────┘└──────────┘└──────────┘ └──────────┘ └──────────┘                                                                                                   ░ └╥┘ ║  ║  ║  ║
# measure: 5/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╩══╩══╩══╩═
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           0  1  2  3  4

# %%
mit_evs_im = []
for depth in depths:
    compiled = noiseless_compiled_perfect_measurment.copy_empty_like()
    for instruction in noiseless_compiled_perfect_measurment.data:
        if instruction.label == "measurement":
            for _ in range(depth):
                for q in get_active_qubits(compiled):
                    compiled.x(q)
        compiled.append(
            instruction, instruction.qubits
        )

    job = computer.run(
        compiled,
        shots=nshots,
    )
    counts = job.result().get_counts()
    ev = get_lst_ev(counts, observable_elements, stabilizer_elements)

    mit_evs_im.append(ev)
    print(ev)
# Out:
# 0.9912606453475404
# 0.9883521397743228
# 0.9827185853353575
# 0.9773091973762001
# 0.963471896146941
# 0.953180322405965
# 0.9368329968272285
# 0.9195890104981013
# 0.9022458701973641
# 0.8826050884955753
# 0.8574514038876889
# 0.8320464857120116
# 0.8090190285863238

# %%
plt.rcParams.update({"font.family": "serif", "font.size": 12})
colors = ["xkcd:blue", "xkcd:orange", "xkcd:red"]
alpha: float = 0.75
stop: int = 15

# plt.title("Measuring $\\langle\\overline{Z}\\rangle$ on $|0\\rangle$ with Steane [[7,1,3]] Code")
plt.ylabel(r"$\langle \bar{Z} \rangle$")
plt.xlabel("Depth")
# plt.plot(depths[:stop], [1.0] * len(depths[:stop]), "--", label="Ideal")
plt.axhline(1.0, label="Ideal", alpha=0.75, color="xkcd:darkgreen")
plt.plot(depths[:stop], unmit_evs[:stop], "--o", color=colors[0], alpha=alpha, mec="black", ms=8, label="Raw")
plt.plot(depths[:stop], mit_evs[:stop], "--o", alpha=alpha, color=colors[1], mec="black", ms=8, label="Encoded")
plt.plot(depths[:stop], mit_evs_im[:stop], "--o", alpha=alpha, color=colors[2], mec="black", ms=8, label="Encoded with Ideal Measurement")
plt.legend()
plt.savefig(f"five_qubit_code_[[5,1,3]]_logical_zero_logical_z_{computer.name}.pdf")
plt.show()
